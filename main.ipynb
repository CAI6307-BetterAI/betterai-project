# %% [markdown]
# # Primary Integration Testing

# %%
from pipeline_01_processing.main import main as pipeline_1
from pipeline_02_retrieval.main import main as pipeline_2

pipeline_1()
pipeline_2()
# Out:
# Data processing pipeline works
# Data retrieval pipeline works
